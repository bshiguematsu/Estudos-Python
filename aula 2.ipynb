# %% [markdown]
# Jupyter Notebook
#
# É um ambiente que viabiliza
# - Execução de codigos
# - criação de documento com texto formatado
# - Plotagem de graficos
#
# > É frequentemente usado para notas de aula

# %% [markdown]
# ![1325984.jpeg](attachment:1325984.jpeg)

# %%
# print - mostra o texto
print ("Hello World!")
# Out:
# Hello World!

# %%
import random
random.randint?

# %%
num = 3

# %%
num = num+2

# %%
num = num*2

# %%
print(num)
# Out:
# 16

# %%
#fazendo contagem de numeros

import time

for i in range(100):
    print(i)
    time.sleep(1)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 5
#       3 for i in range(100):
#       4     print(i)
# ----> 5     time.sleep(1)
#
# KeyboardInterrupt:
